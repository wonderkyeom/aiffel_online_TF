# %%
import random

# %%
end = False

pipe = {'4':16, '8':12, '18':38, '20':74, '24':36, '32':56, '40':60, '48':54, '70':88, '76':86, '80':100, '90':92}
snake = {'22':2, '28':6, '30':10, '44':26, '58':42, '66':14, '68':52, '72':50, '84':62, '94':64, '96':82, '98':78}

# %%
player = int(input("player 수를 입력해주세요."))
print("총 player 수는 ", player, "입니다.")

goal = [0 for i in range(player)]
idx = 1 # 플레이어 넘버
print("시작점 :", goal)
# print(pipe.keys())

if str(goal) in pipe.keys():
    print(True)
    print("key :", pipe[str(goal)])
# Out:
# player 수를 입력해주세요. 4
# 총 player 수는  4 입니다.
# 시작점 : [0, 0, 0, 0]

# %%
while not end:
    # player 정보 출력
    print("현재 player는 ", idx, "번 유저입니다.")
    
    i = random.randint(1, 6)
    print("나온 주사위 값은 ", i, "입니다.")
    print("이동 전 ", idx, "번 플레이어의 위치는 ", goal[idx-1],"입니다.")
    
    if str(i) in pipe.keys():
        # + value만큼
        goal[idx-1] = pipe[str(i)]
    elif str(i) in snake.keys():
        # - value만큼
        goal[idx-1] = snake[str(i)]
    else:
        goal[idx-1] += i

    print("이동 후 player들의 위치는 다음과 같습니다.")
    for p in range(player):
        print(p + 1, "번 플레이어의 위치는", goal[p], "입니다.")
        if goal[p] >= 100:
            print(p + 1, "번 플레이어가 게임에서 승리하셨습니다.")
            end = True
            break
    print(' ')
 
    idx+=1
    if idx > player:
        idx = 1
# Out:
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  1 번 플레이어의 위치는  0 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 3 입니다.
# 2 번 플레이어의 위치는 0 입니다.
# 3 번 플레이어의 위치는 0 입니다.
# 4 번 플레이어의 위치는 0 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  2 번 플레이어의 위치는  0 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 3 입니다.
# 2 번 플레이어의 위치는 6 입니다.
# 3 번 플레이어의 위치는 0 입니다.
# 4 번 플레이어의 위치는 0 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  3 번 플레이어의 위치는  0 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 3 입니다.
# 2 번 플레이어의 위치는 6 입니다.
# 3 번 플레이어의 위치는 1 입니다.
# 4 번 플레이어의 위치는 0 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  4 번 플레이어의 위치는  0 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 3 입니다.
# 2 번 플레이어의 위치는 6 입니다.
# 3 번 플레이어의 위치는 1 입니다.
# 4 번 플레이어의 위치는 16 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  1 번 플레이어의 위치는  3 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 6 입니다.
# 2 번 플레이어의 위치는 6 입니다.
# 3 번 플레이어의 위치는 1 입니다.
# 4 번 플레이어의 위치는 16 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  2 번 플레이어의 위치는  6 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 6 입니다.
# 2 번 플레이어의 위치는 7 입니다.
# 3 번 플레이어의 위치는 1 입니다.
# 4 번 플레이어의 위치는 16 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  3 번 플레이어의 위치는  1 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 6 입니다.
# 2 번 플레이어의 위치는 7 입니다.
# 3 번 플레이어의 위치는 6 입니다.
# 4 번 플레이어의 위치는 16 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  4 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 6 입니다.
# 2 번 플레이어의 위치는 7 입니다.
# 3 번 플레이어의 위치는 6 입니다.
# 4 번 플레이어의 위치는 21 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  1 번 플레이어의 위치는  6 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 9 입니다.
# 2 번 플레이어의 위치는 7 입니다.
# 3 번 플레이어의 위치는 6 입니다.
# 4 번 플레이어의 위치는 21 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  2 번 플레이어의 위치는  7 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 9 입니다.
# 2 번 플레이어의 위치는 9 입니다.
# 3 번 플레이어의 위치는 6 입니다.
# 4 번 플레이어의 위치는 21 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  3 번 플레이어의 위치는  6 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 9 입니다.
# 2 번 플레이어의 위치는 9 입니다.
# 3 번 플레이어의 위치는 7 입니다.
# 4 번 플레이어의 위치는 21 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  4 번 플레이어의 위치는  21 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 9 입니다.
# 2 번 플레이어의 위치는 9 입니다.
# 3 번 플레이어의 위치는 7 입니다.
# 4 번 플레이어의 위치는 16 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  1 번 플레이어의 위치는  9 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 12 입니다.
# 2 번 플레이어의 위치는 9 입니다.
# 3 번 플레이어의 위치는 7 입니다.
# 4 번 플레이어의 위치는 16 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  2 번 플레이어의 위치는  9 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 12 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 7 입니다.
# 4 번 플레이어의 위치는 16 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  3 번 플레이어의 위치는  7 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 12 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 16 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  4 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 12 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 19 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  1 번 플레이어의 위치는  12 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 17 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 19 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  2 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 17 입니다.
# 2 번 플레이어의 위치는 21 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 19 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  3 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 17 입니다.
# 2 번 플레이어의 위치는 21 입니다.
# 3 번 플레이어의 위치는 22 입니다.
# 4 번 플레이어의 위치는 19 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  4 번 플레이어의 위치는  19 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 17 입니다.
# 2 번 플레이어의 위치는 21 입니다.
# 3 번 플레이어의 위치는 22 입니다.
# 4 번 플레이어의 위치는 24 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  1 번 플레이어의 위치는  17 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 20 입니다.
# 2 번 플레이어의 위치는 21 입니다.
# 3 번 플레이어의 위치는 22 입니다.
# 4 번 플레이어의 위치는 24 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  2 번 플레이어의 위치는  21 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 20 입니다.
# 2 번 플레이어의 위치는 24 입니다.
# 3 번 플레이어의 위치는 22 입니다.
# 4 번 플레이어의 위치는 24 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  3 번 플레이어의 위치는  22 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 20 입니다.
# 2 번 플레이어의 위치는 24 입니다.
# 3 번 플레이어의 위치는 27 입니다.
# 4 번 플레이어의 위치는 24 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  4 번 플레이어의 위치는  24 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 20 입니다.
# 2 번 플레이어의 위치는 24 입니다.
# 3 번 플레이어의 위치는 27 입니다.
# 4 번 플레이어의 위치는 26 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  1 번 플레이어의 위치는  20 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 25 입니다.
# 2 번 플레이어의 위치는 24 입니다.
# 3 번 플레이어의 위치는 27 입니다.
# 4 번 플레이어의 위치는 26 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  2 번 플레이어의 위치는  24 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 25 입니다.
# 2 번 플레이어의 위치는 30 입니다.
# 3 번 플레이어의 위치는 27 입니다.
# 4 번 플레이어의 위치는 26 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  3 번 플레이어의 위치는  27 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 25 입니다.
# 2 번 플레이어의 위치는 30 입니다.
# 3 번 플레이어의 위치는 30 입니다.
# 4 번 플레이어의 위치는 26 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  4 번 플레이어의 위치는  26 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 25 입니다.
# 2 번 플레이어의 위치는 30 입니다.
# 3 번 플레이어의 위치는 30 입니다.
# 4 번 플레이어의 위치는 28 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  1 번 플레이어의 위치는  25 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 28 입니다.
# 2 번 플레이어의 위치는 30 입니다.
# 3 번 플레이어의 위치는 30 입니다.
# 4 번 플레이어의 위치는 28 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  2 번 플레이어의 위치는  30 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 28 입니다.
# 2 번 플레이어의 위치는 36 입니다.
# 3 번 플레이어의 위치는 30 입니다.
# 4 번 플레이어의 위치는 28 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  3 번 플레이어의 위치는  30 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 28 입니다.
# 2 번 플레이어의 위치는 36 입니다.
# 3 번 플레이어의 위치는 33 입니다.
# 4 번 플레이어의 위치는 28 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  4 번 플레이어의 위치는  28 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 28 입니다.
# 2 번 플레이어의 위치는 36 입니다.
# 3 번 플레이어의 위치는 33 입니다.
# 4 번 플레이어의 위치는 33 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  1 번 플레이어의 위치는  28 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 31 입니다.
# 2 번 플레이어의 위치는 36 입니다.
# 3 번 플레이어의 위치는 33 입니다.
# 4 번 플레이어의 위치는 33 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  2 번 플레이어의 위치는  36 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 31 입니다.
# 2 번 플레이어의 위치는 37 입니다.
# 3 번 플레이어의 위치는 33 입니다.
# 4 번 플레이어의 위치는 33 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  3 번 플레이어의 위치는  33 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 31 입니다.
# 2 번 플레이어의 위치는 37 입니다.
# 3 번 플레이어의 위치는 36 입니다.
# 4 번 플레이어의 위치는 33 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  4 번 플레이어의 위치는  33 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 31 입니다.
# 2 번 플레이어의 위치는 37 입니다.
# 3 번 플레이어의 위치는 36 입니다.
# 4 번 플레이어의 위치는 16 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  1 번 플레이어의 위치는  31 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 32 입니다.
# 2 번 플레이어의 위치는 37 입니다.
# 3 번 플레이어의 위치는 36 입니다.
# 4 번 플레이어의 위치는 16 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  2 번 플레이어의 위치는  37 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 32 입니다.
# 2 번 플레이어의 위치는 38 입니다.
# 3 번 플레이어의 위치는 36 입니다.
# 4 번 플레이어의 위치는 16 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  3 번 플레이어의 위치는  36 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 32 입니다.
# 2 번 플레이어의 위치는 38 입니다.
# 3 번 플레이어의 위치는 37 입니다.
# 4 번 플레이어의 위치는 16 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  4 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 32 입니다.
# 2 번 플레이어의 위치는 38 입니다.
# 3 번 플레이어의 위치는 37 입니다.
# 4 번 플레이어의 위치는 18 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  1 번 플레이어의 위치는  32 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 35 입니다.
# 2 번 플레이어의 위치는 38 입니다.
# 3 번 플레이어의 위치는 37 입니다.
# 4 번 플레이어의 위치는 18 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  2 번 플레이어의 위치는  38 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 35 입니다.
# 2 번 플레이어의 위치는 44 입니다.
# 3 번 플레이어의 위치는 37 입니다.
# 4 번 플레이어의 위치는 18 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  3 번 플레이어의 위치는  37 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 35 입니다.
# 2 번 플레이어의 위치는 44 입니다.
# 3 번 플레이어의 위치는 40 입니다.
# 4 번 플레이어의 위치는 18 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  4 번 플레이어의 위치는  18 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 35 입니다.
# 2 번 플레이어의 위치는 44 입니다.
# 3 번 플레이어의 위치는 40 입니다.
# 4 번 플레이어의 위치는 21 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  1 번 플레이어의 위치는  35 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 44 입니다.
# 3 번 플레이어의 위치는 40 입니다.
# 4 번 플레이어의 위치는 21 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  2 번 플레이어의 위치는  44 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 47 입니다.
# 3 번 플레이어의 위치는 40 입니다.
# 4 번 플레이어의 위치는 21 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  3 번 플레이어의 위치는  40 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 47 입니다.
# 3 번 플레이어의 위치는 46 입니다.
# 4 번 플레이어의 위치는 21 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  4 번 플레이어의 위치는  21 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 47 입니다.
# 3 번 플레이어의 위치는 46 입니다.
# 4 번 플레이어의 위치는 24 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  1 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 21 입니다.
# 2 번 플레이어의 위치는 47 입니다.
# 3 번 플레이어의 위치는 46 입니다.
# 4 번 플레이어의 위치는 24 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  2 번 플레이어의 위치는  47 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 21 입니다.
# 2 번 플레이어의 위치는 48 입니다.
# 3 번 플레이어의 위치는 46 입니다.
# 4 번 플레이어의 위치는 24 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  3 번 플레이어의 위치는  46 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 21 입니다.
# 2 번 플레이어의 위치는 48 입니다.
# 3 번 플레이어의 위치는 47 입니다.
# 4 번 플레이어의 위치는 24 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  4 번 플레이어의 위치는  24 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 21 입니다.
# 2 번 플레이어의 위치는 48 입니다.
# 3 번 플레이어의 위치는 47 입니다.
# 4 번 플레이어의 위치는 27 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  1 번 플레이어의 위치는  21 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 22 입니다.
# 2 번 플레이어의 위치는 48 입니다.
# 3 번 플레이어의 위치는 47 입니다.
# 4 번 플레이어의 위치는 27 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  2 번 플레이어의 위치는  48 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 22 입니다.
# 2 번 플레이어의 위치는 54 입니다.
# 3 번 플레이어의 위치는 47 입니다.
# 4 번 플레이어의 위치는 27 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  3 번 플레이어의 위치는  47 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 22 입니다.
# 2 번 플레이어의 위치는 54 입니다.
# 3 번 플레이어의 위치는 52 입니다.
# 4 번 플레이어의 위치는 27 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  4 번 플레이어의 위치는  27 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 22 입니다.
# 2 번 플레이어의 위치는 54 입니다.
# 3 번 플레이어의 위치는 52 입니다.
# 4 번 플레이어의 위치는 33 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  1 번 플레이어의 위치는  22 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 23 입니다.
# 2 번 플레이어의 위치는 54 입니다.
# 3 번 플레이어의 위치는 52 입니다.
# 4 번 플레이어의 위치는 33 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  2 번 플레이어의 위치는  54 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 23 입니다.
# 2 번 플레이어의 위치는 57 입니다.
# 3 번 플레이어의 위치는 52 입니다.
# 4 번 플레이어의 위치는 33 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  3 번 플레이어의 위치는  52 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 23 입니다.
# 2 번 플레이어의 위치는 57 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 33 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  4 번 플레이어의 위치는  33 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 23 입니다.
# 2 번 플레이어의 위치는 57 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 35 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  1 번 플레이어의 위치는  23 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 57 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 35 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  2 번 플레이어의 위치는  57 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 58 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 35 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  3 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 58 입니다.
# 3 번 플레이어의 위치는 19 입니다.
# 4 번 플레이어의 위치는 35 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  4 번 플레이어의 위치는  35 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 58 입니다.
# 3 번 플레이어의 위치는 19 입니다.
# 4 번 플레이어의 위치는 40 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  1 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 21 입니다.
# 2 번 플레이어의 위치는 58 입니다.
# 3 번 플레이어의 위치는 19 입니다.
# 4 번 플레이어의 위치는 40 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  2 번 플레이어의 위치는  58 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 21 입니다.
# 2 번 플레이어의 위치는 60 입니다.
# 3 번 플레이어의 위치는 19 입니다.
# 4 번 플레이어의 위치는 40 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  3 번 플레이어의 위치는  19 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 21 입니다.
# 2 번 플레이어의 위치는 60 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 40 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  4 번 플레이어의 위치는  40 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 21 입니다.
# 2 번 플레이어의 위치는 60 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 41 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  1 번 플레이어의 위치는  21 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 23 입니다.
# 2 번 플레이어의 위치는 60 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 41 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  2 번 플레이어의 위치는  60 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 23 입니다.
# 2 번 플레이어의 위치는 62 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 41 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  3 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 23 입니다.
# 2 번 플레이어의 위치는 62 입니다.
# 3 번 플레이어의 위치는 21 입니다.
# 4 번 플레이어의 위치는 41 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  4 번 플레이어의 위치는  41 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 23 입니다.
# 2 번 플레이어의 위치는 62 입니다.
# 3 번 플레이어의 위치는 21 입니다.
# 4 번 플레이어의 위치는 46 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  1 번 플레이어의 위치는  23 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 29 입니다.
# 2 번 플레이어의 위치는 62 입니다.
# 3 번 플레이어의 위치는 21 입니다.
# 4 번 플레이어의 위치는 46 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  2 번 플레이어의 위치는  62 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 29 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 21 입니다.
# 4 번 플레이어의 위치는 46 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  3 번 플레이어의 위치는  21 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 29 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 46 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  4 번 플레이어의 위치는  46 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 29 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 52 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  1 번 플레이어의 위치는  29 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 31 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 52 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  2 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 31 입니다.
# 2 번 플레이어의 위치는 22 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 52 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  3 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 31 입니다.
# 2 번 플레이어의 위치는 22 입니다.
# 3 번 플레이어의 위치는 22 입니다.
# 4 번 플레이어의 위치는 52 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  4 번 플레이어의 위치는  52 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 31 입니다.
# 2 번 플레이어의 위치는 22 입니다.
# 3 번 플레이어의 위치는 22 입니다.
# 4 번 플레이어의 위치는 53 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  1 번 플레이어의 위치는  31 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 37 입니다.
# 2 번 플레이어의 위치는 22 입니다.
# 3 번 플레이어의 위치는 22 입니다.
# 4 번 플레이어의 위치는 53 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  2 번 플레이어의 위치는  22 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 37 입니다.
# 2 번 플레이어의 위치는 28 입니다.
# 3 번 플레이어의 위치는 22 입니다.
# 4 번 플레이어의 위치는 53 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  3 번 플레이어의 위치는  22 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 37 입니다.
# 2 번 플레이어의 위치는 28 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 53 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  4 번 플레이어의 위치는  53 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 37 입니다.
# 2 번 플레이어의 위치는 28 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 55 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  1 번 플레이어의 위치는  37 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 38 입니다.
# 2 번 플레이어의 위치는 28 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 55 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  2 번 플레이어의 위치는  28 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 38 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 55 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  3 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 38 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 55 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  4 번 플레이어의 위치는  55 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 38 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 57 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  1 번 플레이어의 위치는  38 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 57 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  2 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 17 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 57 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  3 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 17 입니다.
# 3 번 플레이어의 위치는 18 입니다.
# 4 번 플레이어의 위치는 57 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  4 번 플레이어의 위치는  57 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 17 입니다.
# 3 번 플레이어의 위치는 18 입니다.
# 4 번 플레이어의 위치는 63 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  1 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 21 입니다.
# 2 번 플레이어의 위치는 17 입니다.
# 3 번 플레이어의 위치는 18 입니다.
# 4 번 플레이어의 위치는 63 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  2 번 플레이어의 위치는  17 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 21 입니다.
# 2 번 플레이어의 위치는 23 입니다.
# 3 번 플레이어의 위치는 18 입니다.
# 4 번 플레이어의 위치는 63 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  3 번 플레이어의 위치는  18 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 21 입니다.
# 2 번 플레이어의 위치는 23 입니다.
# 3 번 플레이어의 위치는 20 입니다.
# 4 번 플레이어의 위치는 63 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  4 번 플레이어의 위치는  63 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 21 입니다.
# 2 번 플레이어의 위치는 23 입니다.
# 3 번 플레이어의 위치는 20 입니다.
# 4 번 플레이어의 위치는 69 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  1 번 플레이어의 위치는  21 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 22 입니다.
# 2 번 플레이어의 위치는 23 입니다.
# 3 번 플레이어의 위치는 20 입니다.
# 4 번 플레이어의 위치는 69 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  2 번 플레이어의 위치는  23 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 22 입니다.
# 2 번 플레이어의 위치는 28 입니다.
# 3 번 플레이어의 위치는 20 입니다.
# 4 번 플레이어의 위치는 69 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  3 번 플레이어의 위치는  20 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 22 입니다.
# 2 번 플레이어의 위치는 28 입니다.
# 3 번 플레이어의 위치는 21 입니다.
# 4 번 플레이어의 위치는 69 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  4 번 플레이어의 위치는  69 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 22 입니다.
# 2 번 플레이어의 위치는 28 입니다.
# 3 번 플레이어의 위치는 21 입니다.
# 4 번 플레이어의 위치는 75 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  1 번 플레이어의 위치는  22 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 24 입니다.
# 2 번 플레이어의 위치는 28 입니다.
# 3 번 플레이어의 위치는 21 입니다.
# 4 번 플레이어의 위치는 75 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  2 번 플레이어의 위치는  28 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 24 입니다.
# 2 번 플레이어의 위치는 30 입니다.
# 3 번 플레이어의 위치는 21 입니다.
# 4 번 플레이어의 위치는 75 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  3 번 플레이어의 위치는  21 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 24 입니다.
# 2 번 플레이어의 위치는 30 입니다.
# 3 번 플레이어의 위치는 24 입니다.
# 4 번 플레이어의 위치는 75 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  4 번 플레이어의 위치는  75 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 24 입니다.
# 2 번 플레이어의 위치는 30 입니다.
# 3 번 플레이어의 위치는 24 입니다.
# 4 번 플레이어의 위치는 76 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  1 번 플레이어의 위치는  24 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 27 입니다.
# 2 번 플레이어의 위치는 30 입니다.
# 3 번 플레이어의 위치는 24 입니다.
# 4 번 플레이어의 위치는 76 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  2 번 플레이어의 위치는  30 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 27 입니다.
# 2 번 플레이어의 위치는 31 입니다.
# 3 번 플레이어의 위치는 24 입니다.
# 4 번 플레이어의 위치는 76 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  3 번 플레이어의 위치는  24 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 27 입니다.
# 2 번 플레이어의 위치는 31 입니다.
# 3 번 플레이어의 위치는 30 입니다.
# 4 번 플레이어의 위치는 76 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  4 번 플레이어의 위치는  76 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 27 입니다.
# 2 번 플레이어의 위치는 31 입니다.
# 3 번 플레이어의 위치는 30 입니다.
# 4 번 플레이어의 위치는 78 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  1 번 플레이어의 위치는  27 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 31 입니다.
# 3 번 플레이어의 위치는 30 입니다.
# 4 번 플레이어의 위치는 78 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  2 번 플레이어의 위치는  31 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 30 입니다.
# 4 번 플레이어의 위치는 78 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  3 번 플레이어의 위치는  30 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 32 입니다.
# 4 번 플레이어의 위치는 78 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  4 번 플레이어의 위치는  78 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 32 입니다.
# 4 번 플레이어의 위치는 16 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  1 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 22 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 32 입니다.
# 4 번 플레이어의 위치는 16 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  2 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 22 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 32 입니다.
# 4 번 플레이어의 위치는 16 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  3 번 플레이어의 위치는  32 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 22 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 38 입니다.
# 4 번 플레이어의 위치는 16 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  4 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 22 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 38 입니다.
# 4 번 플레이어의 위치는 17 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  1 번 플레이어의 위치는  22 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 27 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 38 입니다.
# 4 번 플레이어의 위치는 17 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  2 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 27 입니다.
# 2 번 플레이어의 위치는 22 입니다.
# 3 번 플레이어의 위치는 38 입니다.
# 4 번 플레이어의 위치는 17 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  3 번 플레이어의 위치는  38 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 27 입니다.
# 2 번 플레이어의 위치는 22 입니다.
# 3 번 플레이어의 위치는 43 입니다.
# 4 번 플레이어의 위치는 17 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  4 번 플레이어의 위치는  17 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 27 입니다.
# 2 번 플레이어의 위치는 22 입니다.
# 3 번 플레이어의 위치는 43 입니다.
# 4 번 플레이어의 위치는 22 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  1 번 플레이어의 위치는  27 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 30 입니다.
# 2 번 플레이어의 위치는 22 입니다.
# 3 번 플레이어의 위치는 43 입니다.
# 4 번 플레이어의 위치는 22 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  2 번 플레이어의 위치는  22 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 30 입니다.
# 2 번 플레이어의 위치는 28 입니다.
# 3 번 플레이어의 위치는 43 입니다.
# 4 번 플레이어의 위치는 22 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  3 번 플레이어의 위치는  43 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 30 입니다.
# 2 번 플레이어의 위치는 28 입니다.
# 3 번 플레이어의 위치는 46 입니다.
# 4 번 플레이어의 위치는 22 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  4 번 플레이어의 위치는  22 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 30 입니다.
# 2 번 플레이어의 위치는 28 입니다.
# 3 번 플레이어의 위치는 46 입니다.
# 4 번 플레이어의 위치는 16 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  1 번 플레이어의 위치는  30 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 28 입니다.
# 3 번 플레이어의 위치는 46 입니다.
# 4 번 플레이어의 위치는 16 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  2 번 플레이어의 위치는  28 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 46 입니다.
# 4 번 플레이어의 위치는 16 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  3 번 플레이어의 위치는  46 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 52 입니다.
# 4 번 플레이어의 위치는 16 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  4 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 52 입니다.
# 4 번 플레이어의 위치는 17 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  1 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 21 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 52 입니다.
# 4 번 플레이어의 위치는 17 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  2 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 21 입니다.
# 2 번 플레이어의 위치는 22 입니다.
# 3 번 플레이어의 위치는 52 입니다.
# 4 번 플레이어의 위치는 17 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  3 번 플레이어의 위치는  52 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 21 입니다.
# 2 번 플레이어의 위치는 22 입니다.
# 3 번 플레이어의 위치는 57 입니다.
# 4 번 플레이어의 위치는 17 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  4 번 플레이어의 위치는  17 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 21 입니다.
# 2 번 플레이어의 위치는 22 입니다.
# 3 번 플레이어의 위치는 57 입니다.
# 4 번 플레이어의 위치는 22 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  1 번 플레이어의 위치는  21 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 26 입니다.
# 2 번 플레이어의 위치는 22 입니다.
# 3 번 플레이어의 위치는 57 입니다.
# 4 번 플레이어의 위치는 22 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  2 번 플레이어의 위치는  22 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 26 입니다.
# 2 번 플레이어의 위치는 25 입니다.
# 3 번 플레이어의 위치는 57 입니다.
# 4 번 플레이어의 위치는 22 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  3 번 플레이어의 위치는  57 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 26 입니다.
# 2 번 플레이어의 위치는 25 입니다.
# 3 번 플레이어의 위치는 59 입니다.
# 4 번 플레이어의 위치는 22 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  4 번 플레이어의 위치는  22 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 26 입니다.
# 2 번 플레이어의 위치는 25 입니다.
# 3 번 플레이어의 위치는 59 입니다.
# 4 번 플레이어의 위치는 25 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  1 번 플레이어의 위치는  26 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 31 입니다.
# 2 번 플레이어의 위치는 25 입니다.
# 3 번 플레이어의 위치는 59 입니다.
# 4 번 플레이어의 위치는 25 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  2 번 플레이어의 위치는  25 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 31 입니다.
# 2 번 플레이어의 위치는 31 입니다.
# 3 번 플레이어의 위치는 59 입니다.
# 4 번 플레이어의 위치는 25 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  3 번 플레이어의 위치는  59 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 31 입니다.
# 2 번 플레이어의 위치는 31 입니다.
# 3 번 플레이어의 위치는 60 입니다.
# 4 번 플레이어의 위치는 25 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  4 번 플레이어의 위치는  25 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 31 입니다.
# 2 번 플레이어의 위치는 31 입니다.
# 3 번 플레이어의 위치는 60 입니다.
# 4 번 플레이어의 위치는 28 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  1 번 플레이어의 위치는  31 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 31 입니다.
# 3 번 플레이어의 위치는 60 입니다.
# 4 번 플레이어의 위치는 28 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  2 번 플레이어의 위치는  31 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 60 입니다.
# 4 번 플레이어의 위치는 28 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  3 번 플레이어의 위치는  60 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 61 입니다.
# 4 번 플레이어의 위치는 28 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  4 번 플레이어의 위치는  28 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 61 입니다.
# 4 번 플레이어의 위치는 30 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  1 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 18 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 61 입니다.
# 4 번 플레이어의 위치는 30 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  2 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 18 입니다.
# 2 번 플레이어의 위치는 18 입니다.
# 3 번 플레이어의 위치는 61 입니다.
# 4 번 플레이어의 위치는 30 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  3 번 플레이어의 위치는  61 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 18 입니다.
# 2 번 플레이어의 위치는 18 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 30 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  4 번 플레이어의 위치는  30 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 18 입니다.
# 2 번 플레이어의 위치는 18 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 33 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  1 번 플레이어의 위치는  18 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 23 입니다.
# 2 번 플레이어의 위치는 18 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 33 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  2 번 플레이어의 위치는  18 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 23 입니다.
# 2 번 플레이어의 위치는 19 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 33 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  3 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 23 입니다.
# 2 번 플레이어의 위치는 19 입니다.
# 3 번 플레이어의 위치는 17 입니다.
# 4 번 플레이어의 위치는 33 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  4 번 플레이어의 위치는  33 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 23 입니다.
# 2 번 플레이어의 위치는 19 입니다.
# 3 번 플레이어의 위치는 17 입니다.
# 4 번 플레이어의 위치는 35 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  1 번 플레이어의 위치는  23 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 26 입니다.
# 2 번 플레이어의 위치는 19 입니다.
# 3 번 플레이어의 위치는 17 입니다.
# 4 번 플레이어의 위치는 35 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  2 번 플레이어의 위치는  19 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 26 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 17 입니다.
# 4 번 플레이어의 위치는 35 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  3 번 플레이어의 위치는  17 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 26 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 19 입니다.
# 4 번 플레이어의 위치는 35 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  4 번 플레이어의 위치는  35 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 26 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 19 입니다.
# 4 번 플레이어의 위치는 38 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  1 번 플레이어의 위치는  26 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 31 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 19 입니다.
# 4 번 플레이어의 위치는 38 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  2 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 31 입니다.
# 2 번 플레이어의 위치는 21 입니다.
# 3 번 플레이어의 위치는 19 입니다.
# 4 번 플레이어의 위치는 38 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  3 번 플레이어의 위치는  19 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 31 입니다.
# 2 번 플레이어의 위치는 21 입니다.
# 3 번 플레이어의 위치는 24 입니다.
# 4 번 플레이어의 위치는 38 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  4 번 플레이어의 위치는  38 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 31 입니다.
# 2 번 플레이어의 위치는 21 입니다.
# 3 번 플레이어의 위치는 24 입니다.
# 4 번 플레이어의 위치는 40 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  1 번 플레이어의 위치는  31 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 36 입니다.
# 2 번 플레이어의 위치는 21 입니다.
# 3 번 플레이어의 위치는 24 입니다.
# 4 번 플레이어의 위치는 40 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  2 번 플레이어의 위치는  21 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 36 입니다.
# 2 번 플레이어의 위치는 23 입니다.
# 3 번 플레이어의 위치는 24 입니다.
# 4 번 플레이어의 위치는 40 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  3 번 플레이어의 위치는  24 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 36 입니다.
# 2 번 플레이어의 위치는 23 입니다.
# 3 번 플레이어의 위치는 29 입니다.
# 4 번 플레이어의 위치는 40 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  4 번 플레이어의 위치는  40 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 36 입니다.
# 2 번 플레이어의 위치는 23 입니다.
# 3 번 플레이어의 위치는 29 입니다.
# 4 번 플레이어의 위치는 43 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  1 번 플레이어의 위치는  36 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 37 입니다.
# 2 번 플레이어의 위치는 23 입니다.
# 3 번 플레이어의 위치는 29 입니다.
# 4 번 플레이어의 위치는 43 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  2 번 플레이어의 위치는  23 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 37 입니다.
# 2 번 플레이어의 위치는 26 입니다.
# 3 번 플레이어의 위치는 29 입니다.
# 4 번 플레이어의 위치는 43 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  3 번 플레이어의 위치는  29 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 37 입니다.
# 2 번 플레이어의 위치는 26 입니다.
# 3 번 플레이어의 위치는 34 입니다.
# 4 번 플레이어의 위치는 43 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  4 번 플레이어의 위치는  43 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 37 입니다.
# 2 번 플레이어의 위치는 26 입니다.
# 3 번 플레이어의 위치는 34 입니다.
# 4 번 플레이어의 위치는 49 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  1 번 플레이어의 위치는  37 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 38 입니다.
# 2 번 플레이어의 위치는 26 입니다.
# 3 번 플레이어의 위치는 34 입니다.
# 4 번 플레이어의 위치는 49 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  2 번 플레이어의 위치는  26 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 38 입니다.
# 2 번 플레이어의 위치는 32 입니다.
# 3 번 플레이어의 위치는 34 입니다.
# 4 번 플레이어의 위치는 49 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  3 번 플레이어의 위치는  34 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 38 입니다.
# 2 번 플레이어의 위치는 32 입니다.
# 3 번 플레이어의 위치는 40 입니다.
# 4 번 플레이어의 위치는 49 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  4 번 플레이어의 위치는  49 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 38 입니다.
# 2 번 플레이어의 위치는 32 입니다.
# 3 번 플레이어의 위치는 40 입니다.
# 4 번 플레이어의 위치는 55 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  1 번 플레이어의 위치는  38 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 40 입니다.
# 2 번 플레이어의 위치는 32 입니다.
# 3 번 플레이어의 위치는 40 입니다.
# 4 번 플레이어의 위치는 55 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  2 번 플레이어의 위치는  32 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 40 입니다.
# 2 번 플레이어의 위치는 33 입니다.
# 3 번 플레이어의 위치는 40 입니다.
# 4 번 플레이어의 위치는 55 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  3 번 플레이어의 위치는  40 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 40 입니다.
# 2 번 플레이어의 위치는 33 입니다.
# 3 번 플레이어의 위치는 43 입니다.
# 4 번 플레이어의 위치는 55 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  4 번 플레이어의 위치는  55 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 40 입니다.
# 2 번 플레이어의 위치는 33 입니다.
# 3 번 플레이어의 위치는 43 입니다.
# 4 번 플레이어의 위치는 58 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  1 번 플레이어의 위치는  40 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 43 입니다.
# 2 번 플레이어의 위치는 33 입니다.
# 3 번 플레이어의 위치는 43 입니다.
# 4 번 플레이어의 위치는 58 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  2 번 플레이어의 위치는  33 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 43 입니다.
# 2 번 플레이어의 위치는 35 입니다.
# 3 번 플레이어의 위치는 43 입니다.
# 4 번 플레이어의 위치는 58 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  3 번 플레이어의 위치는  43 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 43 입니다.
# 2 번 플레이어의 위치는 35 입니다.
# 3 번 플레이어의 위치는 49 입니다.
# 4 번 플레이어의 위치는 58 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  4 번 플레이어의 위치는  58 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 43 입니다.
# 2 번 플레이어의 위치는 35 입니다.
# 3 번 플레이어의 위치는 49 입니다.
# 4 번 플레이어의 위치는 63 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  1 번 플레이어의 위치는  43 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 48 입니다.
# 2 번 플레이어의 위치는 35 입니다.
# 3 번 플레이어의 위치는 49 입니다.
# 4 번 플레이어의 위치는 63 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  2 번 플레이어의 위치는  35 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 48 입니다.
# 2 번 플레이어의 위치는 37 입니다.
# 3 번 플레이어의 위치는 49 입니다.
# 4 번 플레이어의 위치는 63 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  3 번 플레이어의 위치는  49 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 48 입니다.
# 2 번 플레이어의 위치는 37 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 63 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  4 번 플레이어의 위치는  63 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 48 입니다.
# 2 번 플레이어의 위치는 37 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 69 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  1 번 플레이어의 위치는  48 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 50 입니다.
# 2 번 플레이어의 위치는 37 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 69 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  2 번 플레이어의 위치는  37 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 50 입니다.
# 2 번 플레이어의 위치는 38 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 69 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  3 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 50 입니다.
# 2 번 플레이어의 위치는 38 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 69 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  4 번 플레이어의 위치는  69 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 50 입니다.
# 2 번 플레이어의 위치는 38 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 75 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  1 번 플레이어의 위치는  50 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 52 입니다.
# 2 번 플레이어의 위치는 38 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 75 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  2 번 플레이어의 위치는  38 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 52 입니다.
# 2 번 플레이어의 위치는 40 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 75 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  3 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 52 입니다.
# 2 번 플레이어의 위치는 40 입니다.
# 3 번 플레이어의 위치는 17 입니다.
# 4 번 플레이어의 위치는 75 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  4 번 플레이어의 위치는  75 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 52 입니다.
# 2 번 플레이어의 위치는 40 입니다.
# 3 번 플레이어의 위치는 17 입니다.
# 4 번 플레이어의 위치는 76 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  1 번 플레이어의 위치는  52 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 40 입니다.
# 3 번 플레이어의 위치는 17 입니다.
# 4 번 플레이어의 위치는 76 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  2 번 플레이어의 위치는  40 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 46 입니다.
# 3 번 플레이어의 위치는 17 입니다.
# 4 번 플레이어의 위치는 76 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  3 번 플레이어의 위치는  17 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 46 입니다.
# 3 번 플레이어의 위치는 22 입니다.
# 4 번 플레이어의 위치는 76 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  4 번 플레이어의 위치는  76 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 46 입니다.
# 3 번 플레이어의 위치는 22 입니다.
# 4 번 플레이어의 위치는 79 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  1 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 46 입니다.
# 3 번 플레이어의 위치는 22 입니다.
# 4 번 플레이어의 위치는 79 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  2 번 플레이어의 위치는  46 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 49 입니다.
# 3 번 플레이어의 위치는 22 입니다.
# 4 번 플레이어의 위치는 79 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  3 번 플레이어의 위치는  22 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 49 입니다.
# 3 번 플레이어의 위치는 24 입니다.
# 4 번 플레이어의 위치는 79 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  4 번 플레이어의 위치는  79 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 49 입니다.
# 3 번 플레이어의 위치는 24 입니다.
# 4 번 플레이어의 위치는 82 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  1 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 21 입니다.
# 2 번 플레이어의 위치는 49 입니다.
# 3 번 플레이어의 위치는 24 입니다.
# 4 번 플레이어의 위치는 82 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  2 번 플레이어의 위치는  49 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 21 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 24 입니다.
# 4 번 플레이어의 위치는 82 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  3 번 플레이어의 위치는  24 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 21 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 82 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  4 번 플레이어의 위치는  82 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 21 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 84 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  1 번 플레이어의 위치는  21 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 22 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 84 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  2 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 22 입니다.
# 2 번 플레이어의 위치는 17 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 84 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  3 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 22 입니다.
# 2 번 플레이어의 위치는 17 입니다.
# 3 번 플레이어의 위치는 17 입니다.
# 4 번 플레이어의 위치는 84 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  4 번 플레이어의 위치는  84 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 22 입니다.
# 2 번 플레이어의 위치는 17 입니다.
# 3 번 플레이어의 위치는 17 입니다.
# 4 번 플레이어의 위치는 85 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  1 번 플레이어의 위치는  22 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 25 입니다.
# 2 번 플레이어의 위치는 17 입니다.
# 3 번 플레이어의 위치는 17 입니다.
# 4 번 플레이어의 위치는 85 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  2 번 플레이어의 위치는  17 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 25 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 17 입니다.
# 4 번 플레이어의 위치는 85 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  3 번 플레이어의 위치는  17 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 25 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 20 입니다.
# 4 번 플레이어의 위치는 85 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  4 번 플레이어의 위치는  85 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 25 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 20 입니다.
# 4 번 플레이어의 위치는 88 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  1 번 플레이어의 위치는  25 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 27 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 20 입니다.
# 4 번 플레이어의 위치는 88 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  2 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 27 입니다.
# 2 번 플레이어의 위치는 21 입니다.
# 3 번 플레이어의 위치는 20 입니다.
# 4 번 플레이어의 위치는 88 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  3 번 플레이어의 위치는  20 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 27 입니다.
# 2 번 플레이어의 위치는 21 입니다.
# 3 번 플레이어의 위치는 22 입니다.
# 4 번 플레이어의 위치는 88 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  4 번 플레이어의 위치는  88 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 27 입니다.
# 2 번 플레이어의 위치는 21 입니다.
# 3 번 플레이어의 위치는 22 입니다.
# 4 번 플레이어의 위치는 90 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  1 번 플레이어의 위치는  27 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 29 입니다.
# 2 번 플레이어의 위치는 21 입니다.
# 3 번 플레이어의 위치는 22 입니다.
# 4 번 플레이어의 위치는 90 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  2 번 플레이어의 위치는  21 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 29 입니다.
# 2 번 플레이어의 위치는 27 입니다.
# 3 번 플레이어의 위치는 22 입니다.
# 4 번 플레이어의 위치는 90 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  3 번 플레이어의 위치는  22 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 29 입니다.
# 2 번 플레이어의 위치는 27 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 90 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  4 번 플레이어의 위치는  90 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 29 입니다.
# 2 번 플레이어의 위치는 27 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 95 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  1 번 플레이어의 위치는  29 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 34 입니다.
# 2 번 플레이어의 위치는 27 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 95 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  2 번 플레이어의 위치는  27 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 34 입니다.
# 2 번 플레이어의 위치는 32 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 95 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  3 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 34 입니다.
# 2 번 플레이어의 위치는 32 입니다.
# 3 번 플레이어의 위치는 22 입니다.
# 4 번 플레이어의 위치는 95 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  4 번 플레이어의 위치는  95 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 34 입니다.
# 2 번 플레이어의 위치는 32 입니다.
# 3 번 플레이어의 위치는 22 입니다.
# 4 번 플레이어의 위치는 98 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  1 번 플레이어의 위치는  34 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 39 입니다.
# 2 번 플레이어의 위치는 32 입니다.
# 3 번 플레이어의 위치는 22 입니다.
# 4 번 플레이어의 위치는 98 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  2 번 플레이어의 위치는  32 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 39 입니다.
# 2 번 플레이어의 위치는 35 입니다.
# 3 번 플레이어의 위치는 22 입니다.
# 4 번 플레이어의 위치는 98 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  3 번 플레이어의 위치는  22 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 39 입니다.
# 2 번 플레이어의 위치는 35 입니다.
# 3 번 플레이어의 위치는 23 입니다.
# 4 번 플레이어의 위치는 98 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  4 번 플레이어의 위치는  98 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 39 입니다.
# 2 번 플레이어의 위치는 35 입니다.
# 3 번 플레이어의 위치는 23 입니다.
# 4 번 플레이어의 위치는 16 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  1 번 플레이어의 위치는  39 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 35 입니다.
# 3 번 플레이어의 위치는 23 입니다.
# 4 번 플레이어의 위치는 16 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  2 번 플레이어의 위치는  35 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 23 입니다.
# 4 번 플레이어의 위치는 16 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  3 번 플레이어의 위치는  23 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 28 입니다.
# 4 번 플레이어의 위치는 16 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  4 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 28 입니다.
# 4 번 플레이어의 위치는 22 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  1 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 22 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 28 입니다.
# 4 번 플레이어의 위치는 22 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  2 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 22 입니다.
# 2 번 플레이어의 위치는 17 입니다.
# 3 번 플레이어의 위치는 28 입니다.
# 4 번 플레이어의 위치는 22 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  3 번 플레이어의 위치는  28 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 22 입니다.
# 2 번 플레이어의 위치는 17 입니다.
# 3 번 플레이어의 위치는 34 입니다.
# 4 번 플레이어의 위치는 22 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  4 번 플레이어의 위치는  22 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 22 입니다.
# 2 번 플레이어의 위치는 17 입니다.
# 3 번 플레이어의 위치는 34 입니다.
# 4 번 플레이어의 위치는 25 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  1 번 플레이어의 위치는  22 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 25 입니다.
# 2 번 플레이어의 위치는 17 입니다.
# 3 번 플레이어의 위치는 34 입니다.
# 4 번 플레이어의 위치는 25 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  2 번 플레이어의 위치는  17 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 25 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 34 입니다.
# 4 번 플레이어의 위치는 25 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  3 번 플레이어의 위치는  34 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 25 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 37 입니다.
# 4 번 플레이어의 위치는 25 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  4 번 플레이어의 위치는  25 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 25 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 37 입니다.
# 4 번 플레이어의 위치는 16 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  1 번 플레이어의 위치는  25 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 27 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 37 입니다.
# 4 번 플레이어의 위치는 16 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  2 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 27 입니다.
# 2 번 플레이어의 위치는 17 입니다.
# 3 번 플레이어의 위치는 37 입니다.
# 4 번 플레이어의 위치는 16 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  3 번 플레이어의 위치는  37 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 27 입니다.
# 2 번 플레이어의 위치는 17 입니다.
# 3 번 플레이어의 위치는 38 입니다.
# 4 번 플레이어의 위치는 16 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  4 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 27 입니다.
# 2 번 플레이어의 위치는 17 입니다.
# 3 번 플레이어의 위치는 38 입니다.
# 4 번 플레이어의 위치는 21 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  1 번 플레이어의 위치는  27 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 29 입니다.
# 2 번 플레이어의 위치는 17 입니다.
# 3 번 플레이어의 위치는 38 입니다.
# 4 번 플레이어의 위치는 21 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  2 번 플레이어의 위치는  17 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 29 입니다.
# 2 번 플레이어의 위치는 23 입니다.
# 3 번 플레이어의 위치는 38 입니다.
# 4 번 플레이어의 위치는 21 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  3 번 플레이어의 위치는  38 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 29 입니다.
# 2 번 플레이어의 위치는 23 입니다.
# 3 번 플레이어의 위치는 39 입니다.
# 4 번 플레이어의 위치는 21 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  4 번 플레이어의 위치는  21 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 29 입니다.
# 2 번 플레이어의 위치는 23 입니다.
# 3 번 플레이어의 위치는 39 입니다.
# 4 번 플레이어의 위치는 23 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  1 번 플레이어의 위치는  29 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 32 입니다.
# 2 번 플레이어의 위치는 23 입니다.
# 3 번 플레이어의 위치는 39 입니다.
# 4 번 플레이어의 위치는 23 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  2 번 플레이어의 위치는  23 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 32 입니다.
# 2 번 플레이어의 위치는 24 입니다.
# 3 번 플레이어의 위치는 39 입니다.
# 4 번 플레이어의 위치는 23 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  3 번 플레이어의 위치는  39 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 32 입니다.
# 2 번 플레이어의 위치는 24 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 23 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  4 번 플레이어의 위치는  23 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 32 입니다.
# 2 번 플레이어의 위치는 24 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 24 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  1 번 플레이어의 위치는  32 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 38 입니다.
# 2 번 플레이어의 위치는 24 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 24 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  2 번 플레이어의 위치는  24 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 38 입니다.
# 2 번 플레이어의 위치는 25 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 24 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  3 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 38 입니다.
# 2 번 플레이어의 위치는 25 입니다.
# 3 번 플레이어의 위치는 17 입니다.
# 4 번 플레이어의 위치는 24 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  4 번 플레이어의 위치는  24 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# ...
# 4 번 플레이어의 위치는 44 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  2 번 플레이어의 위치는  31 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 17 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 17 입니다.
# 4 번 플레이어의 위치는 44 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  3 번 플레이어의 위치는  17 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 17 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 22 입니다.
# 4 번 플레이어의 위치는 44 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  4 번 플레이어의 위치는  44 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 17 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 22 입니다.
# 4 번 플레이어의 위치는 47 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  1 번 플레이어의 위치는  17 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 19 입니다.
# 2 번 플레이어의 위치는 16 입니다.
# 3 번 플레이어의 위치는 22 입니다.
# 4 번 플레이어의 위치는 47 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  2 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 19 입니다.
# 2 번 플레이어의 위치는 19 입니다.
# 3 번 플레이어의 위치는 22 입니다.
# 4 번 플레이어의 위치는 47 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  3 번 플레이어의 위치는  22 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 19 입니다.
# 2 번 플레이어의 위치는 19 입니다.
# 3 번 플레이어의 위치는 24 입니다.
# 4 번 플레이어의 위치는 47 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  4 번 플레이어의 위치는  47 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 19 입니다.
# 2 번 플레이어의 위치는 19 입니다.
# 3 번 플레이어의 위치는 24 입니다.
# 4 번 플레이어의 위치는 53 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  1 번 플레이어의 위치는  19 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 21 입니다.
# 2 번 플레이어의 위치는 19 입니다.
# 3 번 플레이어의 위치는 24 입니다.
# 4 번 플레이어의 위치는 53 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  2 번 플레이어의 위치는  19 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 21 입니다.
# 2 번 플레이어의 위치는 24 입니다.
# 3 번 플레이어의 위치는 24 입니다.
# 4 번 플레이어의 위치는 53 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  3 번 플레이어의 위치는  24 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 21 입니다.
# 2 번 플레이어의 위치는 24 입니다.
# 3 번 플레이어의 위치는 29 입니다.
# 4 번 플레이어의 위치는 53 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  4 번 플레이어의 위치는  53 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 21 입니다.
# 2 번 플레이어의 위치는 24 입니다.
# 3 번 플레이어의 위치는 29 입니다.
# 4 번 플레이어의 위치는 58 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  1 번 플레이어의 위치는  21 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 24 입니다.
# 3 번 플레이어의 위치는 29 입니다.
# 4 번 플레이어의 위치는 58 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  2 번 플레이어의 위치는  24 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 30 입니다.
# 3 번 플레이어의 위치는 29 입니다.
# 4 번 플레이어의 위치는 58 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  3 번 플레이어의 위치는  29 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 30 입니다.
# 3 번 플레이어의 위치는 35 입니다.
# 4 번 플레이어의 위치는 58 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  4 번 플레이어의 위치는  58 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 30 입니다.
# 3 번 플레이어의 위치는 35 입니다.
# 4 번 플레이어의 위치는 64 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  1 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 17 입니다.
# 2 번 플레이어의 위치는 30 입니다.
# 3 번 플레이어의 위치는 35 입니다.
# 4 번 플레이어의 위치는 64 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  2 번 플레이어의 위치는  30 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 17 입니다.
# 2 번 플레이어의 위치는 35 입니다.
# 3 번 플레이어의 위치는 35 입니다.
# 4 번 플레이어의 위치는 64 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  3 번 플레이어의 위치는  35 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 17 입니다.
# 2 번 플레이어의 위치는 35 입니다.
# 3 번 플레이어의 위치는 41 입니다.
# 4 번 플레이어의 위치는 64 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  4 번 플레이어의 위치는  64 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 17 입니다.
# 2 번 플레이어의 위치는 35 입니다.
# 3 번 플레이어의 위치는 41 입니다.
# 4 번 플레이어의 위치는 65 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  1 번 플레이어의 위치는  17 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 19 입니다.
# 2 번 플레이어의 위치는 35 입니다.
# 3 번 플레이어의 위치는 41 입니다.
# 4 번 플레이어의 위치는 65 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  2 번 플레이어의 위치는  35 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 19 입니다.
# 2 번 플레이어의 위치는 38 입니다.
# 3 번 플레이어의 위치는 41 입니다.
# 4 번 플레이어의 위치는 65 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  3 번 플레이어의 위치는  41 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 19 입니다.
# 2 번 플레이어의 위치는 38 입니다.
# 3 번 플레이어의 위치는 44 입니다.
# 4 번 플레이어의 위치는 65 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  4 번 플레이어의 위치는  65 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 19 입니다.
# 2 번 플레이어의 위치는 38 입니다.
# 3 번 플레이어의 위치는 44 입니다.
# 4 번 플레이어의 위치는 66 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  1 번 플레이어의 위치는  19 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 24 입니다.
# 2 번 플레이어의 위치는 38 입니다.
# 3 번 플레이어의 위치는 44 입니다.
# 4 번 플레이어의 위치는 66 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  2 번 플레이어의 위치는  38 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 24 입니다.
# 2 번 플레이어의 위치는 39 입니다.
# 3 번 플레이어의 위치는 44 입니다.
# 4 번 플레이어의 위치는 66 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  3 번 플레이어의 위치는  44 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 24 입니다.
# 2 번 플레이어의 위치는 39 입니다.
# 3 번 플레이어의 위치는 45 입니다.
# 4 번 플레이어의 위치는 66 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  4 번 플레이어의 위치는  66 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 24 입니다.
# 2 번 플레이어의 위치는 39 입니다.
# 3 번 플레이어의 위치는 45 입니다.
# 4 번 플레이어의 위치는 67 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  1 번 플레이어의 위치는  24 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 26 입니다.
# 2 번 플레이어의 위치는 39 입니다.
# 3 번 플레이어의 위치는 45 입니다.
# 4 번 플레이어의 위치는 67 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  2 번 플레이어의 위치는  39 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 26 입니다.
# 2 번 플레이어의 위치는 42 입니다.
# 3 번 플레이어의 위치는 45 입니다.
# 4 번 플레이어의 위치는 67 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  3 번 플레이어의 위치는  45 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 26 입니다.
# 2 번 플레이어의 위치는 42 입니다.
# 3 번 플레이어의 위치는 46 입니다.
# 4 번 플레이어의 위치는 67 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  4 번 플레이어의 위치는  67 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 26 입니다.
# 2 번 플레이어의 위치는 42 입니다.
# 3 번 플레이어의 위치는 46 입니다.
# 4 번 플레이어의 위치는 73 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  1 번 플레이어의 위치는  26 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 31 입니다.
# 2 번 플레이어의 위치는 42 입니다.
# 3 번 플레이어의 위치는 46 입니다.
# 4 번 플레이어의 위치는 73 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  2 번 플레이어의 위치는  42 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 31 입니다.
# 2 번 플레이어의 위치는 48 입니다.
# 3 번 플레이어의 위치는 46 입니다.
# 4 번 플레이어의 위치는 73 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  3 번 플레이어의 위치는  46 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 31 입니다.
# 2 번 플레이어의 위치는 48 입니다.
# 3 번 플레이어의 위치는 52 입니다.
# 4 번 플레이어의 위치는 73 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  4 번 플레이어의 위치는  73 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 31 입니다.
# 2 번 플레이어의 위치는 48 입니다.
# 3 번 플레이어의 위치는 52 입니다.
# 4 번 플레이어의 위치는 16 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  1 번 플레이어의 위치는  31 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 48 입니다.
# 3 번 플레이어의 위치는 52 입니다.
# 4 번 플레이어의 위치는 16 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  2 번 플레이어의 위치는  48 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 54 입니다.
# 3 번 플레이어의 위치는 52 입니다.
# 4 번 플레이어의 위치는 16 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  3 번 플레이어의 위치는  52 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 54 입니다.
# 3 번 플레이어의 위치는 53 입니다.
# 4 번 플레이어의 위치는 16 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  4 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 54 입니다.
# 3 번 플레이어의 위치는 53 입니다.
# 4 번 플레이어의 위치는 19 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  1 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 19 입니다.
# 2 번 플레이어의 위치는 54 입니다.
# 3 번 플레이어의 위치는 53 입니다.
# 4 번 플레이어의 위치는 19 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  2 번 플레이어의 위치는  54 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 19 입니다.
# 2 번 플레이어의 위치는 56 입니다.
# 3 번 플레이어의 위치는 53 입니다.
# 4 번 플레이어의 위치는 19 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  3 번 플레이어의 위치는  53 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 19 입니다.
# 2 번 플레이어의 위치는 56 입니다.
# 3 번 플레이어의 위치는 58 입니다.
# 4 번 플레이어의 위치는 19 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  4 번 플레이어의 위치는  19 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 19 입니다.
# 2 번 플레이어의 위치는 56 입니다.
# 3 번 플레이어의 위치는 58 입니다.
# 4 번 플레이어의 위치는 16 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  1 번 플레이어의 위치는  19 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 24 입니다.
# 2 번 플레이어의 위치는 56 입니다.
# 3 번 플레이어의 위치는 58 입니다.
# 4 번 플레이어의 위치는 16 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  2 번 플레이어의 위치는  56 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 24 입니다.
# 2 번 플레이어의 위치는 58 입니다.
# 3 번 플레이어의 위치는 58 입니다.
# 4 번 플레이어의 위치는 16 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  3 번 플레이어의 위치는  58 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 24 입니다.
# 2 번 플레이어의 위치는 58 입니다.
# 3 번 플레이어의 위치는 60 입니다.
# 4 번 플레이어의 위치는 16 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  4 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 24 입니다.
# 2 번 플레이어의 위치는 58 입니다.
# 3 번 플레이어의 위치는 60 입니다.
# 4 번 플레이어의 위치는 22 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  1 번 플레이어의 위치는  24 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 26 입니다.
# 2 번 플레이어의 위치는 58 입니다.
# 3 번 플레이어의 위치는 60 입니다.
# 4 번 플레이어의 위치는 22 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  2 번 플레이어의 위치는  58 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 26 입니다.
# 2 번 플레이어의 위치는 61 입니다.
# 3 번 플레이어의 위치는 60 입니다.
# 4 번 플레이어의 위치는 22 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  3 번 플레이어의 위치는  60 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 26 입니다.
# 2 번 플레이어의 위치는 61 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 22 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  4 번 플레이어의 위치는  22 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 26 입니다.
# 2 번 플레이어의 위치는 61 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 27 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  1 번 플레이어의 위치는  26 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 32 입니다.
# 2 번 플레이어의 위치는 61 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 27 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  2 번 플레이어의 위치는  61 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 32 입니다.
# 2 번 플레이어의 위치는 67 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 27 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  3 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 32 입니다.
# 2 번 플레이어의 위치는 67 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 27 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  4 번 플레이어의 위치는  27 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 32 입니다.
# 2 번 플레이어의 위치는 67 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 30 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  1 번 플레이어의 위치는  32 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 33 입니다.
# 2 번 플레이어의 위치는 67 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 30 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  2 번 플레이어의 위치는  67 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 33 입니다.
# 2 번 플레이어의 위치는 72 입니다.
# 3 번 플레이어의 위치는 16 입니다.
# 4 번 플레이어의 위치는 30 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  3 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 33 입니다.
# 2 번 플레이어의 위치는 72 입니다.
# 3 번 플레이어의 위치는 17 입니다.
# 4 번 플레이어의 위치는 30 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  4 번 플레이어의 위치는  30 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 33 입니다.
# 2 번 플레이어의 위치는 72 입니다.
# 3 번 플레이어의 위치는 17 입니다.
# 4 번 플레이어의 위치는 16 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  1 번 플레이어의 위치는  33 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 34 입니다.
# 2 번 플레이어의 위치는 72 입니다.
# 3 번 플레이어의 위치는 17 입니다.
# 4 번 플레이어의 위치는 16 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  2 번 플레이어의 위치는  72 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 34 입니다.
# 2 번 플레이어의 위치는 78 입니다.
# 3 번 플레이어의 위치는 17 입니다.
# 4 번 플레이어의 위치는 16 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  3 번 플레이어의 위치는  17 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 34 입니다.
# 2 번 플레이어의 위치는 78 입니다.
# 3 번 플레이어의 위치는 22 입니다.
# 4 번 플레이어의 위치는 16 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  4 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 34 입니다.
# 2 번 플레이어의 위치는 78 입니다.
# 3 번 플레이어의 위치는 22 입니다.
# 4 번 플레이어의 위치는 21 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  1 번 플레이어의 위치는  34 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 35 입니다.
# 2 번 플레이어의 위치는 78 입니다.
# 3 번 플레이어의 위치는 22 입니다.
# 4 번 플레이어의 위치는 21 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  2 번 플레이어의 위치는  78 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 35 입니다.
# 2 번 플레이어의 위치는 80 입니다.
# 3 번 플레이어의 위치는 22 입니다.
# 4 번 플레이어의 위치는 21 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  3 번 플레이어의 위치는  22 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 35 입니다.
# 2 번 플레이어의 위치는 80 입니다.
# 3 번 플레이어의 위치는 27 입니다.
# 4 번 플레이어의 위치는 21 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  4 번 플레이어의 위치는  21 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 35 입니다.
# 2 번 플레이어의 위치는 80 입니다.
# 3 번 플레이어의 위치는 27 입니다.
# 4 번 플레이어의 위치는 22 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  1 번 플레이어의 위치는  35 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 36 입니다.
# 2 번 플레이어의 위치는 80 입니다.
# 3 번 플레이어의 위치는 27 입니다.
# 4 번 플레이어의 위치는 22 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  2 번 플레이어의 위치는  80 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 36 입니다.
# 2 번 플레이어의 위치는 82 입니다.
# 3 번 플레이어의 위치는 27 입니다.
# 4 번 플레이어의 위치는 22 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  3 번 플레이어의 위치는  27 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 36 입니다.
# 2 번 플레이어의 위치는 82 입니다.
# 3 번 플레이어의 위치는 30 입니다.
# 4 번 플레이어의 위치는 22 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  4 번 플레이어의 위치는  22 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 36 입니다.
# 2 번 플레이어의 위치는 82 입니다.
# 3 번 플레이어의 위치는 30 입니다.
# 4 번 플레이어의 위치는 25 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  1 번 플레이어의 위치는  36 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 41 입니다.
# 2 번 플레이어의 위치는 82 입니다.
# 3 번 플레이어의 위치는 30 입니다.
# 4 번 플레이어의 위치는 25 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  2 번 플레이어의 위치는  82 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 41 입니다.
# 2 번 플레이어의 위치는 85 입니다.
# 3 번 플레이어의 위치는 30 입니다.
# 4 번 플레이어의 위치는 25 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  3 번 플레이어의 위치는  30 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 41 입니다.
# 2 번 플레이어의 위치는 85 입니다.
# 3 번 플레이어의 위치는 33 입니다.
# 4 번 플레이어의 위치는 25 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  4 번 플레이어의 위치는  25 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 41 입니다.
# 2 번 플레이어의 위치는 85 입니다.
# 3 번 플레이어의 위치는 33 입니다.
# 4 번 플레이어의 위치는 28 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  1 번 플레이어의 위치는  41 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 43 입니다.
# 2 번 플레이어의 위치는 85 입니다.
# 3 번 플레이어의 위치는 33 입니다.
# 4 번 플레이어의 위치는 28 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  5 입니다.
# 이동 전  2 번 플레이어의 위치는  85 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 43 입니다.
# 2 번 플레이어의 위치는 90 입니다.
# 3 번 플레이어의 위치는 33 입니다.
# 4 번 플레이어의 위치는 28 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  2 입니다.
# 이동 전  3 번 플레이어의 위치는  33 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 43 입니다.
# 2 번 플레이어의 위치는 90 입니다.
# 3 번 플레이어의 위치는 35 입니다.
# 4 번 플레이어의 위치는 28 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  1 입니다.
# 이동 전  4 번 플레이어의 위치는  28 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 43 입니다.
# 2 번 플레이어의 위치는 90 입니다.
# 3 번 플레이어의 위치는 35 입니다.
# 4 번 플레이어의 위치는 29 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  4 입니다.
# 이동 전  1 번 플레이어의 위치는  43 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 90 입니다.
# 3 번 플레이어의 위치는 35 입니다.
# 4 번 플레이어의 위치는 29 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  2 번 플레이어의 위치는  90 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 96 입니다.
# 3 번 플레이어의 위치는 35 입니다.
# 4 번 플레이어의 위치는 29 입니다.
#
# 현재 player는  3 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  3 번 플레이어의 위치는  35 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 96 입니다.
# 3 번 플레이어의 위치는 41 입니다.
# 4 번 플레이어의 위치는 29 입니다.
#
# 현재 player는  4 번 유저입니다.
# 나온 주사위 값은  3 입니다.
# 이동 전  4 번 플레이어의 위치는  29 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 16 입니다.
# 2 번 플레이어의 위치는 96 입니다.
# 3 번 플레이어의 위치는 41 입니다.
# 4 번 플레이어의 위치는 32 입니다.
#
# 현재 player는  1 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  1 번 플레이어의 위치는  16 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 22 입니다.
# 2 번 플레이어의 위치는 96 입니다.
# 3 번 플레이어의 위치는 41 입니다.
# 4 번 플레이어의 위치는 32 입니다.
#
# 현재 player는  2 번 유저입니다.
# 나온 주사위 값은  6 입니다.
# 이동 전  2 번 플레이어의 위치는  96 입니다.
# 이동 후 player들의 위치는 다음과 같습니다.
# 1 번 플레이어의 위치는 22 입니다.
# 2 번 플레이어의 위치는 102 입니다.
# 2 번 플레이어가 게임에서 승리하셨습니다.
